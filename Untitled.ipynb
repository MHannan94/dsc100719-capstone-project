# %%
import pickle
import pandas as pd
import numpy as np
import cv2
import matplotlib.pyplot as plt
# %matplotlib inline
import autoreload
from sklearn.model_selection import train_test_split
from keras.models import Model, load_model, Sequential
from keras.layers import Dense,Conv2D,Flatten,MaxPool2D,Dropout,BatchNormalization, Input
from keras.models import load_model
# %load_ext autoreload
# %autoreload 2
# Out:
# Using TensorFlow backend.

# %%
data = pickle.load(open('cleaned_training.p', 'rb'))

# %%
from data_functions import create_training_data

# %%
X, Y_root, Y_vowel, Y_consonant = create_training_data(data)

# %%
x_train, x_test, y_train_root, y_test_root, y_train_vowel, y_test_vowel, y_train_consonant, y_test_consonant = train_test_split(X, Y_root, Y_vowel, Y_consonant, test_size=0.05, random_state=42)
y_train = [y_train_root, y_train_vowel, y_train_consonant]
y_test = [y_test_root, y_test_vowel, y_test_consonant]

# %%
class_map_df = pd.read_csv('data/class_map.csv')

# %%
from create_models import ModelEvaluation

# %%
inputs = Input(shape = (64, 64, 1))

model = Conv2D(filters=32, kernel_size=(3, 3), padding='SAME', activation='relu', input_shape=(64, 64, 1))(inputs)
model = Conv2D(filters=32, kernel_size= (3,3), padding='SAME', activation='relu')(model)
model = BatchNormalization(momentum=0.15)(model)
model = MaxPool2D(pool_size=(2, 2))(model)
model = Conv2D(filters=32, kernel_size= (5,5), padding='SAME', activation='relu')(model)
model = BatchNormalization(momentum=0.15)(model)
model = Dropout(rate=0.2)(model)

model = Conv2D(filters=64, kernel_size=(3, 3), padding='SAME', activation='relu')(model)
model = BatchNormalization(momentum=0.15)(model)
model = MaxPool2D(pool_size=(2, 2))(model)
model = Conv2D(filters=64, kernel_size= (5,5), padding='SAME', activation='relu')(model)
model = BatchNormalization(momentum=0.15)(model)
model = Dropout(rate=0.2)(model)

model = Conv2D(filters=128, kernel_size=(3, 3), padding='SAME', activation='relu')(model)
model = BatchNormalization(momentum=0.15)(model)
model = Conv2D(filters=128, kernel_size= (5,5), padding='SAME', activation='relu')(model)
model = BatchNormalization(momentum=0.15)(model)
model = MaxPool2D(pool_size=(2, 2))(model)
model = Dropout(rate=0.2)(model)

model = Flatten()(model)
model = Dense(1024, activation = "relu")(model)
model = Dropout(rate=0.3)(model)
dense = Dense(512, activation = 'relu')(model)

root = Dense(168, activation = 'softmax')(dense)
vowel = Dense(11, activation = 'softmax')(dense)
consonant = Dense(7, activation = 'softmax')(dense)

model = Model(inputs=inputs, outputs=[root, vowel, consonant])

# %%
mymodel= ModelEvaluation(model)
# Out:
# Model: "model_1"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_1 (InputLayer)            (None, 64, 64, 1)    0
# __________________________________________________________________________________________________
# conv2d_1 (Conv2D)               (None, 64, 64, 32)   320         input_1[0][0]
# __________________________________________________________________________________________________
# conv2d_2 (Conv2D)               (None, 64, 64, 32)   9248        conv2d_1[0][0]
# __________________________________________________________________________________________________
# batch_normalization_1 (BatchNor (None, 64, 64, 32)   128         conv2d_2[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_1 (MaxPooling2D)  (None, 32, 32, 32)   0           batch_normalization_1[0][0]
# __________________________________________________________________________________________________
# conv2d_3 (Conv2D)               (None, 32, 32, 32)   25632       max_pooling2d_1[0][0]
# __________________________________________________________________________________________________
# batch_normalization_2 (BatchNor (None, 32, 32, 32)   128         conv2d_3[0][0]
# __________________________________________________________________________________________________
# dropout_1 (Dropout)             (None, 32, 32, 32)   0           batch_normalization_2[0][0]
# __________________________________________________________________________________________________
# conv2d_4 (Conv2D)               (None, 32, 32, 64)   18496       dropout_1[0][0]
# __________________________________________________________________________________________________
# batch_normalization_3 (BatchNor (None, 32, 32, 64)   256         conv2d_4[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_2 (MaxPooling2D)  (None, 16, 16, 64)   0           batch_normalization_3[0][0]
# __________________________________________________________________________________________________
# conv2d_5 (Conv2D)               (None, 16, 16, 64)   102464      max_pooling2d_2[0][0]
# __________________________________________________________________________________________________
# batch_normalization_4 (BatchNor (None, 16, 16, 64)   256         conv2d_5[0][0]
# __________________________________________________________________________________________________
# dropout_2 (Dropout)             (None, 16, 16, 64)   0           batch_normalization_4[0][0]
# __________________________________________________________________________________________________
# conv2d_6 (Conv2D)               (None, 16, 16, 128)  73856       dropout_2[0][0]
# __________________________________________________________________________________________________
# batch_normalization_5 (BatchNor (None, 16, 16, 128)  512         conv2d_6[0][0]
# __________________________________________________________________________________________________
# conv2d_7 (Conv2D)               (None, 16, 16, 128)  409728      batch_normalization_5[0][0]
# __________________________________________________________________________________________________
# batch_normalization_6 (BatchNor (None, 16, 16, 128)  512         conv2d_7[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_3 (MaxPooling2D)  (None, 8, 8, 128)    0           batch_normalization_6[0][0]
# __________________________________________________________________________________________________
# dropout_3 (Dropout)             (None, 8, 8, 128)    0           max_pooling2d_3[0][0]
# __________________________________________________________________________________________________
# flatten_1 (Flatten)             (None, 8192)         0           dropout_3[0][0]
# __________________________________________________________________________________________________
# dense_1 (Dense)                 (None, 1024)         8389632     flatten_1[0][0]
# __________________________________________________________________________________________________
# dropout_4 (Dropout)             (None, 1024)         0           dense_1[0][0]
# __________________________________________________________________________________________________
# dense_2 (Dense)                 (None, 512)          524800      dropout_4[0][0]
# __________________________________________________________________________________________________
# dense_3 (Dense)                 (None, 168)          86184       dense_2[0][0]
# __________________________________________________________________________________________________
# dense_4 (Dense)                 (None, 11)           5643        dense_2[0][0]
# __________________________________________________________________________________________________
# dense_5 (Dense)                 (None, 7)            3591        dense_2[0][0]
# ==================================================================================================
# Total params: 9,651,386
# Trainable params: 9,650,490
# Non-trainable params: 896
# __________________________________________________________________________________________________

# %%
mymodel.train(x_train, y_train, epochs= 20, batch_size= 256, validation_split= 0.1)
# Out:
# Train on 171718 samples, validate on 19080 samples
# Epoch 1/20
# 171718/171718 [==============================] - 253s 1ms/step - loss: 5.7439 - dense_3_loss: 3.9768 - dense_4_loss: 0.9651 - dense_5_loss: 0.8013 - dense_3_accuracy: 0.0995 - dense_4_accuracy: 0.6815 - dense_5_accuracy: 0.7371 - val_loss: 3.5271 - val_dense_3_loss: 2.6655 - val_dense_4_loss: 0.4808 - val_dense_5_loss: 0.3817 - val_dense_3_accuracy: 0.2842 - val_dense_4_accuracy: 0.8348 - val_dense_5_accuracy: 0.8714
# Epoch 2/20
# 171718/171718 [==============================] - 244s 1ms/step - loss: 2.4834 - dense_3_loss: 1.8227 - dense_4_loss: 0.3612 - dense_5_loss: 0.2992 - dense_3_accuracy: 0.4751 - dense_4_accuracy: 0.8782 - dense_5_accuracy: 0.9000 - val_loss: 1.2708 - val_dense_3_loss: 0.8916 - val_dense_4_loss: 0.2014 - val_dense_5_loss: 0.1790 - val_dense_3_accuracy: 0.7348 - val_dense_4_accuracy: 0.9344 - val_dense_5_accuracy: 0.9437
# Epoch 3/20
# 171718/171718 [==============================] - 244s 1ms/step - loss: 1.3407 - dense_3_loss: 0.9299 - dense_4_loss: 0.2210 - dense_5_loss: 0.1897 - dense_3_accuracy: 0.7240 - dense_4_accuracy: 0.9294 - dense_5_accuracy: 0.9389 - val_loss: 0.8476 - val_dense_3_loss: 0.5689 - val_dense_4_loss: 0.1434 - val_dense_5_loss: 0.1356 - val_dense_3_accuracy: 0.8316 - val_dense_4_accuracy: 0.9557 - val_dense_5_accuracy: 0.9587
# Epoch 4/20
# 171718/171718 [==============================] - 243s 1ms/step - loss: 0.9714 - dense_3_loss: 0.6607 - dense_4_loss: 0.1633 - dense_5_loss: 0.1474 - dense_3_accuracy: 0.8039 - dense_4_accuracy: 0.9482 - dense_5_accuracy: 0.9529 - val_loss: 0.7026 - val_dense_3_loss: 0.4643 - val_dense_4_loss: 0.1205 - val_dense_5_loss: 0.1177 - val_dense_3_accuracy: 0.8633 - val_dense_4_accuracy: 0.9640 - val_dense_5_accuracy: 0.9637
# Epoch 5/20
# 171718/171718 [==============================] - 244s 1ms/step - loss: 0.7950 - dense_3_loss: 0.5360 - dense_4_loss: 0.1366 - dense_5_loss: 0.1223 - dense_3_accuracy: 0.8409 - dense_4_accuracy: 0.9578 - dense_5_accuracy: 0.9615 - val_loss: 0.6378 - val_dense_3_loss: 0.4264 - val_dense_4_loss: 0.1099 - val_dense_5_loss: 0.1023 - val_dense_3_accuracy: 0.8782 - val_dense_4_accuracy: 0.9672 - val_dense_5_accuracy: 0.9701
# Epoch 6/20
# 171718/171718 [==============================] - 244s 1ms/step - loss: 0.6844 - dense_3_loss: 0.4590 - dense_4_loss: 0.1172 - dense_5_loss: 0.1082 - dense_3_accuracy: 0.8623 - dense_4_accuracy: 0.9638 - dense_5_accuracy: 0.9657 - val_loss: 0.7369 - val_dense_3_loss: 0.4690 - val_dense_4_loss: 0.1538 - val_dense_5_loss: 0.1147 - val_dense_3_accuracy: 0.8652 - val_dense_4_accuracy: 0.9548 - val_dense_5_accuracy: 0.9658
# Epoch 7/20
# 171718/171718 [==============================] - 243s 1ms/step - loss: 0.6054 - dense_3_loss: 0.4064 - dense_4_loss: 0.1035 - dense_5_loss: 0.0956 - dense_3_accuracy: 0.8771 - dense_4_accuracy: 0.9686 - dense_5_accuracy: 0.9700 - val_loss: 0.5801 - val_dense_3_loss: 0.3931 - val_dense_4_loss: 0.0956 - val_dense_5_loss: 0.0912 - val_dense_3_accuracy: 0.8872 - val_dense_4_accuracy: 0.9728 - val_dense_5_accuracy: 0.9725
# Epoch 8/20
# 171718/171718 [==============================] - 243s 1ms/step - loss: 0.5506 - dense_3_loss: 0.3679 - dense_4_loss: 0.0943 - dense_5_loss: 0.0885 - dense_3_accuracy: 0.8886 - dense_4_accuracy: 0.9711 - dense_5_accuracy: 0.9722 - val_loss: 0.5383 - val_dense_3_loss: 0.3568 - val_dense_4_loss: 0.0922 - val_dense_5_loss: 0.0899 - val_dense_3_accuracy: 0.9002 - val_dense_4_accuracy: 0.9756 - val_dense_5_accuracy: 0.9736
# Epoch 9/20
# 171718/171718 [==============================] - 245s 1ms/step - loss: 0.4963 - dense_3_loss: 0.3314 - dense_4_loss: 0.0852 - dense_5_loss: 0.0797 - dense_3_accuracy: 0.8988 - dense_4_accuracy: 0.9743 - dense_5_accuracy: 0.9748 - val_loss: 0.5555 - val_dense_3_loss: 0.3660 - val_dense_4_loss: 0.0988 - val_dense_5_loss: 0.0912 - val_dense_3_accuracy: 0.9002 - val_dense_4_accuracy: 0.9735 - val_dense_5_accuracy: 0.9731
# Epoch 10/20
# 171718/171718 [==============================] - 244s 1ms/step - loss: 0.4638 - dense_3_loss: 0.3094 - dense_4_loss: 0.0791 - dense_5_loss: 0.0754 - dense_3_accuracy: 0.9051 - dense_4_accuracy: 0.9758 - dense_5_accuracy: 0.9756 - val_loss: 0.5219 - val_dense_3_loss: 0.3415 - val_dense_4_loss: 0.0932 - val_dense_5_loss: 0.0874 - val_dense_3_accuracy: 0.9053 - val_dense_4_accuracy: 0.9748 - val_dense_5_accuracy: 0.9756
# Epoch 11/20
# 171718/171718 [==============================] - 243s 1ms/step - loss: 0.4238 - dense_3_loss: 0.2822 - dense_4_loss: 0.0731 - dense_5_loss: 0.0684 - dense_3_accuracy: 0.9131 - dense_4_accuracy: 0.9775 - dense_5_accuracy: 0.9784 - val_loss: 0.5231 - val_dense_3_loss: 0.3409 - val_dense_4_loss: 0.0918 - val_dense_5_loss: 0.0912 - val_dense_3_accuracy: 0.9078 - val_dense_4_accuracy: 0.9768 - val_dense_5_accuracy: 0.9753
# Epoch 12/20
# 171718/171718 [==============================] - 245s 1ms/step - loss: 0.3945 - dense_3_loss: 0.2626 - dense_4_loss: 0.0677 - dense_5_loss: 0.0642 - dense_3_accuracy: 0.9184 - dense_4_accuracy: 0.9796 - dense_5_accuracy: 0.9795 - val_loss: 0.5027 - val_dense_3_loss: 0.3270 - val_dense_4_loss: 0.0916 - val_dense_5_loss: 0.0846 - val_dense_3_accuracy: 0.9110 - val_dense_4_accuracy: 0.9756 - val_dense_5_accuracy: 0.9763
# Epoch 13/20
# 171718/171718 [==============================] - 245s 1ms/step - loss: 0.3683 - dense_3_loss: 0.2456 - dense_4_loss: 0.0625 - dense_5_loss: 0.0602 - dense_3_accuracy: 0.9239 - dense_4_accuracy: 0.9809 - dense_5_accuracy: 0.9807 - val_loss: 0.4951 - val_dense_3_loss: 0.3213 - val_dense_4_loss: 0.0896 - val_dense_5_loss: 0.0850 - val_dense_3_accuracy: 0.9162 - val_dense_4_accuracy: 0.9760 - val_dense_5_accuracy: 0.9760
# Epoch 14/20
# 171718/171718 [==============================] - 244s 1ms/step - loss: 0.3437 - dense_3_loss: 0.2300 - dense_4_loss: 0.0570 - dense_5_loss: 0.0567 - dense_3_accuracy: 0.9279 - dense_4_accuracy: 0.9825 - dense_5_accuracy: 0.9821 - val_loss: 0.5007 - val_dense_3_loss: 0.3239 - val_dense_4_loss: 0.0904 - val_dense_5_loss: 0.0871 - val_dense_3_accuracy: 0.9126 - val_dense_4_accuracy: 0.9769 - val_dense_5_accuracy: 0.9763
# Epoch 15/20
# 171718/171718 [==============================] - 243s 1ms/step - loss: 0.3189 - dense_3_loss: 0.2122 - dense_4_loss: 0.0553 - dense_5_loss: 0.0515 - dense_3_accuracy: 0.9330 - dense_4_accuracy: 0.9829 - dense_5_accuracy: 0.9831 - val_loss: 0.5135 - val_dense_3_loss: 0.3333 - val_dense_4_loss: 0.0972 - val_dense_5_loss: 0.0837 - val_dense_3_accuracy: 0.9113 - val_dense_4_accuracy: 0.9746 - val_dense_5_accuracy: 0.9778
# Epoch 16/20
# 171718/171718 [==============================] - 243s 1ms/step - loss: 0.2989 - dense_3_loss: 0.1998 - dense_4_loss: 0.0515 - dense_5_loss: 0.0475 - dense_3_accuracy: 0.9368 - dense_4_accuracy: 0.9846 - dense_5_accuracy: 0.9848 - val_loss: 0.4803 - val_dense_3_loss: 0.3114 - val_dense_4_loss: 0.0858 - val_dense_5_loss: 0.0836 - val_dense_3_accuracy: 0.9192 - val_dense_4_accuracy: 0.9781 - val_dense_5_accuracy: 0.9790
# Epoch 17/20
# 171718/171718 [==============================] - 243s 1ms/step - loss: 0.2803 - dense_3_loss: 0.1860 - dense_4_loss: 0.0478 - dense_5_loss: 0.0465 - dense_3_accuracy: 0.9398 - dense_4_accuracy: 0.9852 - dense_5_accuracy: 0.9852 - val_loss: 0.5009 - val_dense_3_loss: 0.3281 - val_dense_4_loss: 0.0875 - val_dense_5_loss: 0.0863 - val_dense_3_accuracy: 0.9153 - val_dense_4_accuracy: 0.9790 - val_dense_5_accuracy: 0.9778
# Epoch 18/20
# 171718/171718 [==============================] - 244s 1ms/step - loss: 0.2604 - dense_3_loss: 0.1741 - dense_4_loss: 0.0440 - dense_5_loss: 0.0423 - dense_3_accuracy: 0.9440 - dense_4_accuracy: 0.9864 - dense_5_accuracy: 0.9862 - val_loss: 0.5051 - val_dense_3_loss: 0.3244 - val_dense_4_loss: 0.0940 - val_dense_5_loss: 0.0875 - val_dense_3_accuracy: 0.9172 - val_dense_4_accuracy: 0.9764 - val_dense_5_accuracy: 0.9773
# Epoch 19/20
# 171718/171718 [==============================] - 243s 1ms/step - loss: 0.2477 - dense_3_loss: 0.1648 - dense_4_loss: 0.0424 - dense_5_loss: 0.0405 - dense_3_accuracy: 0.9470 - dense_4_accuracy: 0.9866 - dense_5_accuracy: 0.9867 - val_loss: 0.4990 - val_dense_3_loss: 0.3241 - val_dense_4_loss: 0.0875 - val_dense_5_loss: 0.0881 - val_dense_3_accuracy: 0.9207 - val_dense_4_accuracy: 0.9794 - val_dense_5_accuracy: 0.9787
# Epoch 20/20
# 171718/171718 [==============================] - 243s 1ms/step - loss: 0.2362 - dense_3_loss: 0.1583 - dense_4_loss: 0.0392 - dense_5_loss: 0.0387 - dense_3_accuracy: 0.9487 - dense_4_accuracy: 0.9879 - dense_5_accuracy: 0.9872 - val_loss: 0.5048 - val_dense_3_loss: 0.3318 - val_dense_4_loss: 0.0875 - val_dense_5_loss: 0.0860 - val_dense_3_accuracy: 0.9189 - val_dense_4_accuracy: 0.9788 - val_dense_5_accuracy: 0.9784

# %%
mymodel.plot_metrics()

# %%
mymodel.test(class_map_df, x_test, y_test, 10)
# Out:
#         predicted                                      true               \
#              root r_comp vowel v_comp consonant c_comp root r_comp vowel
# image_0       107      ব     2      ি         0      0  107      ব     2
# image_1       107      ব     0      0         5     ্র  107      ব     0
# image_2        71      থ     0      0         3    র্য   71      থ     0
# image_3       146    ষ্ম     0      0         0      0  146    ষ্ম     0
# image_4       133      শ    10      ৌ         0      0  133      শ    10
# image_5        22      খ     3      ী         5     ্র   22      খ     3
# image_6        83    ন্ট     2      ি         5     ্র   83    ন্ট     2
# image_7        81      ন     7      ে         4     ্য   81      ন     7
# image_8        22      খ     2      ি         5     ্র   22      খ     2
# image_9        72      দ     0      0         0      0   72      দ     0
#
#
#         v_comp consonant c_comp
# image_0      ি         0      0
# image_1      0         5     ্র
# image_2      0         3    র্য
# image_3      0         0      0
# image_4      ৌ         0      0
# image_5      ী         5     ্র
# image_6      ি         5     ্র
# image_7      ে         4     ্য
# image_8      ি         5     ্র
# image_9      0         0      0

# %%
mymodel.evaluation(x_test, y_test)
# Out:
# 10042/10042 [==============================] - 7s 731us/step
# [('loss', 0.48649813937276654), ('dense_3_loss', 0.3130292594432831), ('dense_4_loss', 0.08786999434232712), ('dense_5_loss', 0.08592486381530762), ('dense_3_accuracy', 0.9215295910835266), ('dense_4_accuracy', 0.9800836443901062), ('dense_5_accuracy', 0.9783907532691956)]

# %%
mymodel.save_model()

# %%
# initial model
model= load_model('model_1.h5')
hist = pickle.load(open('model_1_history.p', 'rb'))

# %%
mymodel= ModelEvaluation(model, hist)
# Out:
# Model: "model_2"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_2 (InputLayer)            (None, 64, 64, 1)    0
# __________________________________________________________________________________________________
# conv2d_2 (Conv2D)               (None, 64, 64, 32)   320         input_2[0][0]
# __________________________________________________________________________________________________
# batch_normalization_2 (BatchNor (None, 64, 64, 32)   128         conv2d_2[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_2 (MaxPooling2D)  (None, 32, 32, 32)   0           batch_normalization_2[0][0]
# __________________________________________________________________________________________________
# dropout_2 (Dropout)             (None, 32, 32, 32)   0           max_pooling2d_2[0][0]
# __________________________________________________________________________________________________
# flatten_2 (Flatten)             (None, 32768)        0           dropout_2[0][0]
# __________________________________________________________________________________________________
# dense_5 (Dense)                 (None, 1024)         33555456    flatten_2[0][0]
# __________________________________________________________________________________________________
# dense_6 (Dense)                 (None, 168)          172200      dense_5[0][0]
# __________________________________________________________________________________________________
# dense_7 (Dense)                 (None, 11)           11275       dense_5[0][0]
# __________________________________________________________________________________________________
# dense_8 (Dense)                 (None, 7)            7175        dense_5[0][0]
# ==================================================================================================
# Total params: 33,746,554
# Trainable params: 33,746,490
# Non-trainable params: 64
# __________________________________________________________________________________________________

# %%
mymodel.plot_metrics()

# %%
mymodel.test(class_map_df, x_test, y_test, 5)
# Out:
#         predicted                                      true               \
#              root r_comp vowel v_comp consonant c_comp root r_comp vowel
# image_0        72      দ     2      ি         2     র্  124      ল     2
# image_1       119    ম্ভ     1      া         0      0  119    ম্ভ     1
# image_2       132    ল্ল     4      ু         0      0  132    ল্ল     4
# image_3        71      থ     9      ো         2     র্   86    ন্ত     9
# image_4       153    স্প     7      ে         0      0  101    প্ল     7
#
#
#         v_comp consonant c_comp
# image_0      ি         2     র্
# image_1      া         0      0
# image_2      ু         0      0
# image_3      ো         0      0
# image_4      ে         0      0

# %%
mymodel.evaluation(x_test, y_test)
# Out:
# 10042/10042 [==============================] - 4s 404us/step
# [('loss', 7.584911674646903), ('dense_6_loss', 5.39757776260376), ('dense_7_loss', 1.1051106452941895), ('dense_8_loss', 1.0843908786773682), ('dense_6_accuracy', 0.3494323790073395), ('dense_7_accuracy', 0.8118900656700134), ('dense_8_accuracy', 0.8322047591209412)]

# %%
model= load_model('model_8.h5')
hist = pickle.load(open('model_8_history.p', 'rb'))

# %%
mymodel = ModelEvaluation(model, hist)
# Out:
# Model: "model_1"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_1 (InputLayer)            (None, 64, 64, 1)    0
# __________________________________________________________________________________________________
# conv2d_1 (Conv2D)               (None, 64, 64, 32)   320         input_1[0][0]
# __________________________________________________________________________________________________
# conv2d_2 (Conv2D)               (None, 64, 64, 32)   9248        conv2d_1[0][0]
# __________________________________________________________________________________________________
# batch_normalization_1 (BatchNor (None, 64, 64, 32)   128         conv2d_2[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_1 (MaxPooling2D)  (None, 32, 32, 32)   0           batch_normalization_1[0][0]
# __________________________________________________________________________________________________
# conv2d_3 (Conv2D)               (None, 32, 32, 32)   25632       max_pooling2d_1[0][0]
# __________________________________________________________________________________________________
# batch_normalization_2 (BatchNor (None, 32, 32, 32)   128         conv2d_3[0][0]
# __________________________________________________________________________________________________
# dropout_1 (Dropout)             (None, 32, 32, 32)   0           batch_normalization_2[0][0]
# __________________________________________________________________________________________________
# conv2d_4 (Conv2D)               (None, 32, 32, 64)   18496       dropout_1[0][0]
# __________________________________________________________________________________________________
# batch_normalization_3 (BatchNor (None, 32, 32, 64)   256         conv2d_4[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_2 (MaxPooling2D)  (None, 16, 16, 64)   0           batch_normalization_3[0][0]
# __________________________________________________________________________________________________
# conv2d_5 (Conv2D)               (None, 16, 16, 64)   102464      max_pooling2d_2[0][0]
# __________________________________________________________________________________________________
# batch_normalization_4 (BatchNor (None, 16, 16, 64)   256         conv2d_5[0][0]
# __________________________________________________________________________________________________
# dropout_2 (Dropout)             (None, 16, 16, 64)   0           batch_normalization_4[0][0]
# __________________________________________________________________________________________________
# conv2d_6 (Conv2D)               (None, 16, 16, 128)  73856       dropout_2[0][0]
# __________________________________________________________________________________________________
# batch_normalization_5 (BatchNor (None, 16, 16, 128)  512         conv2d_6[0][0]
# __________________________________________________________________________________________________
# conv2d_7 (Conv2D)               (None, 16, 16, 128)  409728      batch_normalization_5[0][0]
# __________________________________________________________________________________________________
# batch_normalization_6 (BatchNor (None, 16, 16, 128)  512         conv2d_7[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_3 (MaxPooling2D)  (None, 8, 8, 128)    0           batch_normalization_6[0][0]
# __________________________________________________________________________________________________
# dropout_3 (Dropout)             (None, 8, 8, 128)    0           max_pooling2d_3[0][0]
# __________________________________________________________________________________________________
# flatten_1 (Flatten)             (None, 8192)         0           dropout_3[0][0]
# __________________________________________________________________________________________________
# dense_1 (Dense)                 (None, 1024)         8389632     flatten_1[0][0]
# __________________________________________________________________________________________________
# dropout_4 (Dropout)             (None, 1024)         0           dense_1[0][0]
# __________________________________________________________________________________________________
# dense_2 (Dense)                 (None, 512)          524800      dropout_4[0][0]
# __________________________________________________________________________________________________
# dense_3 (Dense)                 (None, 168)          86184       dense_2[0][0]
# __________________________________________________________________________________________________
# dense_4 (Dense)                 (None, 11)           5643        dense_2[0][0]
# __________________________________________________________________________________________________
# dense_5 (Dense)                 (None, 7)            3591        dense_2[0][0]
# ==================================================================================================
# Total params: 9,651,386
# Trainable params: 9,650,490
# Non-trainable params: 896
# __________________________________________________________________________________________________

# %%
mymodel.plot_metrics()

# %%
mymodel.test(class_map_df, x_test, y_test, 5)
# Out:
#         predicted                                      true               \
#              root r_comp vowel v_comp consonant c_comp root r_comp vowel
# image_0        71      থ     7      ে         4     ্য   71      থ     7
# image_1       132    ল্ল     0      0         0      0  132    ল্ল     0
# image_2        56      ড     2      ি         5     ্র   56      ড     2
# image_3       115      ম     9      ো         0      0  115      ম     9
# image_4        38      চ     2      ি         0      0   38      চ     2
#
#
#         v_comp consonant c_comp
# image_0      ে         4     ্য
# image_1      0         0      0
# image_2      ি         5     ্র
# image_3      ো         0      0
# image_4      ি         0      0

# %%
mymodel.evaluation(x_test, y_test)
# Out:
# 10042/10042 [==============================] - 7s 741us/step
# [('loss', 0.48649813691545496), ('dense_3_loss', 0.3130292594432831), ('dense_4_loss', 0.08786999434232712), ('dense_5_loss', 0.08592486381530762), ('dense_3_accuracy', 0.9215295910835266), ('dense_4_accuracy', 0.9800836443901062), ('dense_5_accuracy', 0.9783907532691956)]

# %%
92
